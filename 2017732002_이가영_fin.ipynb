# %%
import os
import torch
import torch.nn as nn
from torchtext.legacy import data, datasets 
from google.colab import drive
drive.mount('/content/drive')

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# for reproducibility
torch.manual_seed(777)
if device == 'cuda':
    torch.cuda.manual_seed_all(777)

# parameters
batch_size = 64
learning_rate = 0.001
# Out:
# Mounted at /content/drive
# cuda

# %%
# 문제 1번

TEXT = data.Field(sequential=True, batch_first=True, lower=True)
LABEL = data.Field(sequential=False, batch_first=True)
trainset, valset, testset = datasets.SST.splits(TEXT, LABEL)


TEXT.build_vocab(trainset, min_freq=5)# TEXT 데이터를 기반으로 Vocab 생성
LABEL.build_vocab(trainset)# LABEL 데이터를 기반으로 Vocab 생성

TEXT.build_vocab(valset, min_freq=5)# TEXT 데이터를 기반으로 Vocab 생성
LABEL.build_vocab(valset)# LABEL 데이터를 기반으로 Vocab 생성

# 매 배치마다 비슷한 길이에 맞춰 줄 수 있도록 iterator 정의
train_iter, val_iter, test_iter = data.BucketIterator.splits(   # 134 18 34
        (trainset, valset, testset), batch_size=batch_size,
        shuffle=True, repeat=False)

vocab_size = len(TEXT.vocab)
n_classes = 3 # Positive, Negative Class가 두 개

print("[TrainSet]: %d [ValSet]: %d [TestSet]: %d [Vocab]: %d [Classes] %d"
      % (len(trainset),len(valset), len(testset), vocab_size, n_classes))

# %%
class BasicGRU(nn.Module):
    def __init__(self, n_layers, hidden_dim, n_vocab, embed_dim, n_classes, dropout_p=0.2):
        super(BasicGRU, self).__init__()
        self.n_layers = n_layers 

        #n_vocab : Vocab 안에 있는 단어의 개수, embed_dim : 임베딩 된 단어 텐서가 갖는 차원 값(dimension)
        self.embed = nn.Embedding(n_vocab, embed_dim)

        # hidden vector의 dimension과 dropout 정의
        self.hidden_dim = hidden_dim
        self.dropout = nn.Dropout(dropout_p)

        #앞에서 정의한 하이퍼 파라미터를 넣어 GRU 정의
        self.gru = nn.GRU(embed_dim, self.hidden_dim,
                          num_layers=self.n_layers,
                          batch_first=True)
        
        #Input: GRU의 hidden vector(context), Output : Class probability vector
        self.out = nn.Linear(self.hidden_dim, n_classes)

    def forward(self, x):
        # Input data: 한 batch 내 모든 영화 평가 데이터
        
        x = self.embed(x)# 영화 평 임베딩
        x, _ = self.gru(x)  # [i, b, h] 출력값 :  (batch_size, 입력 x의 길이, hidden_dim)

        # h_t : Batch 내 모든 sequential hidden state vector의 제일 마지막 토큰을 내포한 (batch_size, 1, hidden_dim)형태의 텐서 추출
        # 다른 의미로 영화 리뷰 배열들을 압축한 hidden state vector
        h_t = x[:,-1,:]

        self.dropout(h_t)# dropout 설정 후, 

        # linear layer의 입력으로 주고, 각 클래스 별 결과 logit을 생성.
        out = self.out(h_t)  # [b, h] -> [b, o]
        return out

# %%
# contruct model
model = BasicGRU(1, 256, vocab_size, 128, n_classes, 0.5).to(device)

# define cost/loss & optimizer
criterion = torch.nn.CrossEntropyLoss().to(device)    # Softmax
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)



# 문제 2번
last_accuracy = 0
epoch = 0
while(1):    # 2-1
  epoch += 1
  avg_cost = 0
  for batch in train_iter:
    X, Y = batch.text.to(device), batch.label.to(device)   # 64, 46 / 64

    Y.data.sub_(1)
    optimizer.zero_grad()
    hypothesis = model(X)
    

    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()
    avg_cost += cost / batch_size
  print('[Epoch: {:>4}] cost = {:>.9}'.format(epoch, avg_cost))



  # 2-2
  corrects = 0
  for batch in val_iter:
    x, y = batch.text, batch.label
    X = torch.LongTensor(x).to(device)
    Y = torch.LongTensor(y).to(device)

    Y.data.sub_(1)
    hypothesis = model(X)

    corrects += (hypothesis.max(1)[1].view(y.size()).data == Y.data).sum()

  # print(corrects)
  # print(len(val_iter.dataset))

  accuracy = corrects/len(val_iter.dataset)*100.0
  print("이때, val의 accuracy : ", float(accuracy))
  
  

  if accuracy == last_accuracy : 
    count += 1

  else:
    count = 0


  # 2-3. accuracy가 2 번의 epoch 이상의 기간동안 증가하지 않으면 학습을 멈추고, accuracy가 최고일 때의 model을 저장하도록 구현
  if count == 3:
    # 모델저장
    print("두 epoch이상 기간동안 증가하지 않아 모델을 저장하고, 학습을 종료합니다.")
    torch.save(model.state_dict(), '/content/drive/MyDrive/model_s1.pt')
    break   # while문 빠져나오기
  
  last_accuracy == accuracy
# Out:
# [Epoch:    1] cost = 2.2122364
# 이때, val의 accuracy :  40.8719367980957
# [Epoch:    2] cost = 2.16712189
# 이때, val의 accuracy :  48.2288818359375
# [Epoch:    3] cost = 2.0148437
# 이때, val의 accuracy :  57.1298828125
# [Epoch:    4] cost = 1.86797512
# 이때, val의 accuracy :  57.22071075439453
# [Epoch:    5] cost = 1.71701515
# 이때, val의 accuracy :  55.13169860839844
# [Epoch:    6] cost = 1.53887594
# 이때, val의 accuracy :  56.40327453613281
# [Epoch:    7] cost = 1.30974412
# 이때, val의 accuracy :  55.222530364990234
# [Epoch:    8] cost = 1.02393436
# 이때, val의 accuracy :  55.676658630371094
# [Epoch:    9] cost = 0.708362281
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:   10] cost = 0.488790512
# 이때, val의 accuracy :  51.68029022216797
# [Epoch:   11] cost = 0.355434388
# 이때, val의 accuracy :  50.22706985473633
# [Epoch:   12] cost = 0.257385433
# 이때, val의 accuracy :  51.86194610595703
# [Epoch:   13] cost = 0.211493611
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:   14] cost = 0.180284739
# 이때, val의 accuracy :  51.95277404785156
# [Epoch:   15] cost = 0.162414148
# 이때, val의 accuracy :  52.225250244140625
# [Epoch:   16] cost = 0.15029332
# 이때, val의 accuracy :  49.7729377746582
# [Epoch:   17] cost = 0.138574615
# 이때, val의 accuracy :  48.138057708740234
# [Epoch:   18] cost = 0.182442427
# 이때, val의 accuracy :  52.04359817504883
# [Epoch:   19] cost = 0.129757598
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:   20] cost = 0.113974407
# 이때, val의 accuracy :  51.407814025878906
# [Epoch:   21] cost = 0.113490239
# 이때, val의 accuracy :  51.49863815307617
# [Epoch:   22] cost = 0.118554004
# 이때, val의 accuracy :  52.588558197021484
# [Epoch:   23] cost = 0.0966520384
# 이때, val의 accuracy :  52.225250244140625
# [Epoch:   24] cost = 0.0820178613
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:   25] cost = 0.124010526
# 이때, val의 accuracy :  54.58673858642578
# [Epoch:   26] cost = 0.0980851725
# 이때, val의 accuracy :  52.13442611694336
# [Epoch:   27] cost = 0.0864183754
# 이때, val의 accuracy :  52.86103439331055
# [Epoch:   28] cost = 0.0695186704
# 이때, val의 accuracy :  54.495914459228516
# [Epoch:   29] cost = 0.0790494978
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:   30] cost = 0.107562825
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:   31] cost = 0.114185035
# 이때, val의 accuracy :  54.13261032104492
# [Epoch:   32] cost = 0.0911181718
# 이때, val의 accuracy :  55.222530364990234
# [Epoch:   33] cost = 0.15592584
# 이때, val의 accuracy :  52.86103439331055
# [Epoch:   34] cost = 0.101132356
# 이때, val의 accuracy :  53.224342346191406
# [Epoch:   35] cost = 0.0734422505
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:   36] cost = 0.0653390512
# 이때, val의 accuracy :  52.31607437133789
# [Epoch:   37] cost = 0.0753904507
# 이때, val의 accuracy :  52.225250244140625
# [Epoch:   38] cost = 0.0682009161
# 이때, val의 accuracy :  54.67757034301758
# [Epoch:   39] cost = 0.101076081
# 이때, val의 accuracy :  53.224342346191406
# [Epoch:   40] cost = 0.0948287398
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:   41] cost = 0.0799175873
# 이때, val의 accuracy :  51.226158142089844
# [Epoch:   42] cost = 0.0628357604
# 이때, val의 accuracy :  52.40690612792969
# [Epoch:   43] cost = 0.0589431487
# 이때, val의 accuracy :  51.407814025878906
# [Epoch:   44] cost = 0.0662723258
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:   45] cost = 0.110088423
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:   46] cost = 0.100999236
# 이때, val의 accuracy :  52.49773406982422
# [Epoch:   47] cost = 0.10108427
# 이때, val의 accuracy :  52.225250244140625
# [Epoch:   48] cost = 0.0799465626
# 이때, val의 accuracy :  53.04269027709961
# [Epoch:   49] cost = 0.0594835207
# 이때, val의 accuracy :  52.225250244140625
# [Epoch:   50] cost = 0.0534744896
# 이때, val의 accuracy :  52.49773406982422
# [Epoch:   51] cost = 0.052135814
# 이때, val의 accuracy :  53.13351821899414
# [Epoch:   52] cost = 0.0505959392
# 이때, val의 accuracy :  54.31426239013672
# [Epoch:   53] cost = 0.0489953756
# 이때, val의 accuracy :  53.04269027709961
# [Epoch:   54] cost = 0.0490325838
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:   55] cost = 0.0519176498
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:   56] cost = 0.05134793
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:   57] cost = 0.0481388643
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:   58] cost = 0.0465303995
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:   59] cost = 0.0467259064
# 이때, val의 accuracy :  52.951866149902344
# [Epoch:   60] cost = 0.0473567471
# 이때, val의 accuracy :  52.588558197021484
# [Epoch:   61] cost = 0.0461414307
# 이때, val의 accuracy :  52.13442611694336
# [Epoch:   62] cost = 0.0458481424
# 이때, val의 accuracy :  52.951866149902344
# [Epoch:   63] cost = 0.0451591238
# 이때, val의 accuracy :  53.04269027709961
# [Epoch:   64] cost = 0.0495040528
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:   65] cost = 0.0470471308
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:   66] cost = 0.0485992692
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:   67] cost = 0.0485007726
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:   68] cost = 0.0492467843
# 이때, val의 accuracy :  52.13442611694336
# [Epoch:   69] cost = 0.341204405
# 이때, val의 accuracy :  51.7711181640625
# [Epoch:   70] cost = 0.191706568
# 이때, val의 accuracy :  51.7711181640625
# [Epoch:   71] cost = 0.111998193
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:   72] cost = 0.0874723941
# 이때, val의 accuracy :  51.31698989868164
# [Epoch:   73] cost = 0.0956219584
# 이때, val의 accuracy :  54.31426239013672
# [Epoch:   74] cost = 0.0875651464
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:   75] cost = 0.0905281678
# 이때, val의 accuracy :  52.86103439331055
# [Epoch:   76] cost = 0.0742125586
# 이때, val의 accuracy :  54.31426239013672
# [Epoch:   77] cost = 0.0647021681
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:   78] cost = 0.0714572817
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:   79] cost = 0.0580818355
# 이때, val의 accuracy :  53.04269027709961
# [Epoch:   80] cost = 0.0867867246
# 이때, val의 accuracy :  51.95277404785156
# [Epoch:   81] cost = 0.0997613147
# 이때, val의 accuracy :  51.68029022216797
# [Epoch:   82] cost = 0.0861689746
# 이때, val의 accuracy :  51.68029022216797
# [Epoch:   83] cost = 0.064600274
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:   84] cost = 0.0608821809
# 이때, val의 accuracy :  52.49773406982422
# [Epoch:   85] cost = 0.0651063547
# 이때, val의 accuracy :  53.13351821899414
# [Epoch:   86] cost = 0.0625402257
# 이때, val의 accuracy :  51.7711181640625
# [Epoch:   87] cost = 0.0596319325
# 이때, val의 accuracy :  54.13261032104492
# [Epoch:   88] cost = 0.0580015481
# 이때, val의 accuracy :  52.77021026611328
# [Epoch:   89] cost = 0.0502896197
# 이때, val의 accuracy :  52.13442611694336
# [Epoch:   90] cost = 0.0507890545
# 이때, val의 accuracy :  52.951866149902344
# [Epoch:   91] cost = 0.0722320154
# 이때, val의 accuracy :  52.951866149902344
# [Epoch:   92] cost = 0.10097225
# 이때, val의 accuracy :  52.49773406982422
# [Epoch:   93] cost = 0.0961606577
# 이때, val의 accuracy :  52.04359817504883
# [Epoch:   94] cost = 0.0831526443
# 이때, val의 accuracy :  53.13351821899414
# [Epoch:   95] cost = 0.0660194084
# 이때, val의 accuracy :  54.95004653930664
# [Epoch:   96] cost = 0.048189234
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:   97] cost = 0.0446482189
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:   98] cost = 0.0430903174
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:   99] cost = 0.0487161577
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:  100] cost = 0.0467050634
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:  101] cost = 0.0442799851
# 이때, val의 accuracy :  54.31426239013672
# [Epoch:  102] cost = 0.0425814018
# 이때, val의 accuracy :  54.859222412109375
# [Epoch:  103] cost = 0.0425333753
# 이때, val의 accuracy :  54.31426239013672
# [Epoch:  104] cost = 0.0426787175
# 이때, val의 accuracy :  53.95095443725586
# [Epoch:  105] cost = 0.0415606909
# 이때, val의 accuracy :  54.95004653930664
# [Epoch:  106] cost = 0.0412558913
# 이때, val의 accuracy :  54.495914459228516
# [Epoch:  107] cost = 0.0415284187
# 이때, val의 accuracy :  54.95004653930664
# [Epoch:  108] cost = 0.0426622927
# 이때, val의 accuracy :  53.95095443725586
# [Epoch:  109] cost = 0.0438333228
# 이때, val의 accuracy :  53.49681854248047
# [Epoch:  110] cost = 0.0435687341
# 이때, val의 accuracy :  53.224342346191406
# [Epoch:  111] cost = 0.0446691215
# 이때, val의 accuracy :  53.95095443725586
# [Epoch:  112] cost = 0.0462958254
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  113] cost = 0.0441940986
# 이때, val의 accuracy :  53.224342346191406
# [Epoch:  114] cost = 0.0425218195
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:  115] cost = 0.0420749821
# 이때, val의 accuracy :  53.95095443725586
# [Epoch:  116] cost = 0.040611051
# 이때, val의 accuracy :  53.04269027709961
# [Epoch:  117] cost = 0.0460801534
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:  118] cost = 0.0427855924
# 이때, val의 accuracy :  54.22343444824219
# [Epoch:  119] cost = 0.0418191329
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:  120] cost = 0.0509094037
# 이때, val의 accuracy :  53.49681854248047
# [Epoch:  121] cost = 0.268036932
# 이때, val의 accuracy :  49.86376190185547
# [Epoch:  122] cost = 0.243496329
# 이때, val의 accuracy :  49.7729377746582
# [Epoch:  123] cost = 0.0929734334
# 이때, val의 accuracy :  50.86285400390625
# [Epoch:  124] cost = 0.0608939081
# 이때, val의 accuracy :  51.407814025878906
# [Epoch:  125] cost = 0.0548963733
# 이때, val의 accuracy :  50.317893981933594
# [Epoch:  126] cost = 0.070333384
# 이때, val의 accuracy :  53.04269027709961
# [Epoch:  127] cost = 0.0838787109
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:  128] cost = 0.0756701082
# 이때, val의 accuracy :  51.95277404785156
# [Epoch:  129] cost = 0.0704214498
# 이때, val의 accuracy :  50.68119812011719
# [Epoch:  130] cost = 0.0870972723
# 이때, val의 accuracy :  52.31607437133789
# [Epoch:  131] cost = 0.112283766
# 이때, val의 accuracy :  51.31698989868164
# [Epoch:  132] cost = 0.094239153
# 이때, val의 accuracy :  51.7711181640625
# [Epoch:  133] cost = 0.0789364204
# 이때, val의 accuracy :  51.04450607299805
# [Epoch:  134] cost = 0.0561437607
# 이때, val의 accuracy :  51.04450607299805
# [Epoch:  135] cost = 0.0472622402
# 이때, val의 accuracy :  51.13533020019531
# [Epoch:  136] cost = 0.0441905037
# 이때, val의 accuracy :  51.226158142089844
# [Epoch:  137] cost = 0.0426502228
# 이때, val의 accuracy :  51.31698989868164
# [Epoch:  138] cost = 0.0430662595
# 이때, val의 accuracy :  51.226158142089844
# [Epoch:  139] cost = 0.0419634469
# 이때, val의 accuracy :  50.86285400390625
# [Epoch:  140] cost = 0.0424405672
# 이때, val의 accuracy :  51.226158142089844
# [Epoch:  141] cost = 0.0418899916
# 이때, val의 accuracy :  50.772029876708984
# [Epoch:  142] cost = 0.0423120745
# 이때, val의 accuracy :  50.95368194580078
# [Epoch:  143] cost = 0.0425937735
# 이때, val의 accuracy :  51.13533020019531
# [Epoch:  144] cost = 0.0410164967
# 이때, val의 accuracy :  50.772029876708984
# [Epoch:  145] cost = 0.0412113555
# 이때, val의 accuracy :  51.31698989868164
# [Epoch:  146] cost = 0.0408733636
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:  147] cost = 0.0502801612
# 이때, val의 accuracy :  50.49954605102539
# [Epoch:  148] cost = 0.0449757278
# 이때, val의 accuracy :  51.13533020019531
# [Epoch:  149] cost = 0.0425526835
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:  150] cost = 0.0411942936
# 이때, val의 accuracy :  51.7711181640625
# [Epoch:  151] cost = 0.0430549197
# 이때, val의 accuracy :  51.407814025878906
# [Epoch:  152] cost = 0.0424132124
# 이때, val의 accuracy :  50.95368194580078
# [Epoch:  153] cost = 0.0412439257
# 이때, val의 accuracy :  51.49863815307617
# [Epoch:  154] cost = 0.0414942503
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:  155] cost = 0.0404370576
# 이때, val의 accuracy :  52.04359817504883
# [Epoch:  156] cost = 0.0410146117
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:  157] cost = 0.0407413095
# 이때, val의 accuracy :  51.226158142089844
# [Epoch:  158] cost = 0.0416578613
# 이때, val의 accuracy :  51.04450607299805
# [Epoch:  159] cost = 0.04101431
# 이때, val의 accuracy :  51.5894660949707
# [Epoch:  160] cost = 0.0420734212
# 이때, val의 accuracy :  51.04450607299805
# [Epoch:  161] cost = 0.0414093211
# 이때, val의 accuracy :  52.04359817504883
# [Epoch:  162] cost = 0.0604675859
# 이때, val의 accuracy :  51.13533020019531
# [Epoch:  163] cost = 0.347528458
# 이때, val의 accuracy :  51.95277404785156
# [Epoch:  164] cost = 0.21022515
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  165] cost = 0.0804059878
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:  166] cost = 0.0526255891
# 이때, val의 accuracy :  54.22343444824219
# [Epoch:  167] cost = 0.0490968153
# 이때, val의 accuracy :  55.222530364990234
# [Epoch:  168] cost = 0.0491483659
# 이때, val의 accuracy :  55.222530364990234
# [Epoch:  169] cost = 0.0435504429
# 이때, val의 accuracy :  54.768394470214844
# [Epoch:  170] cost = 0.0443517342
# 이때, val의 accuracy :  54.859222412109375
# [Epoch:  171] cost = 0.0437964089
# 이때, val의 accuracy :  55.040870666503906
# [Epoch:  172] cost = 0.0449207611
# 이때, val의 accuracy :  54.95004653930664
# [Epoch:  173] cost = 0.0418547913
# 이때, val의 accuracy :  54.768394470214844
# [Epoch:  174] cost = 0.0408520438
# 이때, val의 accuracy :  55.13169860839844
# [Epoch:  175] cost = 0.0416147672
# 이때, val의 accuracy :  54.67757034301758
# [Epoch:  176] cost = 0.0419932604
# 이때, val의 accuracy :  55.3133544921875
# [Epoch:  177] cost = 0.0408407934
# 이때, val의 accuracy :  55.13169860839844
# [Epoch:  178] cost = 0.0408642925
# 이때, val의 accuracy :  54.859222412109375
# [Epoch:  179] cost = 0.0414781198
# 이때, val의 accuracy :  54.95004653930664
# [Epoch:  180] cost = 0.0417238027
# 이때, val의 accuracy :  54.859222412109375
# [Epoch:  181] cost = 0.0416904911
# 이때, val의 accuracy :  54.95004653930664
# [Epoch:  182] cost = 0.0417566486
# 이때, val의 accuracy :  55.222530364990234
# [Epoch:  183] cost = 0.0393389054
# 이때, val의 accuracy :  55.4950065612793
# [Epoch:  184] cost = 0.0418900177
# 이때, val의 accuracy :  56.40327453613281
# [Epoch:  185] cost = 0.0445040651
# 이때, val의 accuracy :  54.31426239013672
# [Epoch:  186] cost = 0.0527328514
# 이때, val의 accuracy :  55.040870666503906
# [Epoch:  187] cost = 0.25925675
# 이때, val의 accuracy :  52.77021026611328
# [Epoch:  188] cost = 0.236153051
# 이때, val의 accuracy :  53.13351821899414
# [Epoch:  189] cost = 0.113295719
# 이때, val의 accuracy :  52.40690612792969
# [Epoch:  190] cost = 0.0633844286
# 이때, val의 accuracy :  52.86103439331055
# [Epoch:  191] cost = 0.0483184271
# 이때, val의 accuracy :  53.49681854248047
# [Epoch:  192] cost = 0.0443785936
# 이때, val의 accuracy :  53.13351821899414
# [Epoch:  193] cost = 0.0444418378
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:  194] cost = 0.0440498851
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  195] cost = 0.0428087711
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  196] cost = 0.0427586436
# 이때, val의 accuracy :  53.86012649536133
# [Epoch:  197] cost = 0.0418174751
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:  198] cost = 0.0417554043
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:  199] cost = 0.0423639081
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:  200] cost = 0.0423179604
# 이때, val의 accuracy :  54.13261032104492
# [Epoch:  201] cost = 0.0413962528
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  202] cost = 0.0423080809
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  203] cost = 0.0415654071
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:  204] cost = 0.0420088656
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:  205] cost = 0.0409276336
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:  206] cost = 0.0413178913
# 이때, val의 accuracy :  54.22343444824219
# [Epoch:  207] cost = 0.0411637388
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:  208] cost = 0.0407998301
# 이때, val의 accuracy :  53.95095443725586
# [Epoch:  209] cost = 0.0414334871
# 이때, val의 accuracy :  53.86012649536133
# [Epoch:  210] cost = 0.0415323526
# 이때, val의 accuracy :  53.76930236816406
# [Epoch:  211] cost = 0.0420320854
# 이때, val의 accuracy :  54.67757034301758
# [Epoch:  212] cost = 0.0414274037
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:  213] cost = 0.0423093066
# 이때, val의 accuracy :  54.13261032104492
# [Epoch:  214] cost = 0.0431839153
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:  215] cost = 0.0428274795
# 이때, val의 accuracy :  54.67757034301758
# [Epoch:  216] cost = 0.0423556641
# 이때, val의 accuracy :  53.587650299072266
# [Epoch:  217] cost = 0.0534765571
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:  218] cost = 0.369779289
# 이때, val의 accuracy :  53.95095443725586
# [Epoch:  219] cost = 0.253522962
# 이때, val의 accuracy :  55.94913864135742
# [Epoch:  220] cost = 0.0954019651
# 이때, val의 accuracy :  55.222530364990234
# [Epoch:  221] cost = 0.0638380498
# 이때, val의 accuracy :  54.041778564453125
# [Epoch:  222] cost = 0.04940084
# 이때, val의 accuracy :  54.13261032104492
# [Epoch:  223] cost = 0.0506924391
# 이때, val의 accuracy :  53.4059944152832
# [Epoch:  224] cost = 0.0491854064
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:  225] cost = 0.0489613824
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:  226] cost = 0.0480594225
# 이때, val의 accuracy :  53.31517028808594
# [Epoch:  227] cost = 0.0505899303
# 이때, val의 accuracy :  52.77021026611328
# [Epoch:  228] cost = 0.0903666839
# 이때, val의 accuracy :  53.6784782409668
# [Epoch:  229] cost = 0.140151396
# 이때, val의 accuracy :  52.951866149902344
# [Epoch:  230] cost = 0.125016898
# 이때, val의 accuracy :  52.951866149902344
# [Epoch:  231] cost = 0.0864748284
# 이때, val의 accuracy :  53.13351821899414
# [Epoch:  232] cost = 0.0570630357
# 이때, val의 accuracy :  54.495914459228516
# [Epoch:  233] cost = 0.049488809
# 이때, val의 accuracy :  54.405086517333984
# [Epoch:  234] cost = 0.0428929217
# 이때, val의 accuracy :  55.3133544921875

# %%
# 4번
model_new = BasicGRU(1, 256, vocab_size, 128, n_classes, 0.5).to(device)
model_new.load_state_dict(torch.load('/content/drive/MyDrive/model_s1.pt'))

corrects = 0
for batch in test_iter:
  x,y = batch.text.to(device), batch.label.to(device)
  y.data.sub_(1)
  hypothesis = model_new(x)
  
  corrects += (hypothesis.max(1)[1].view(y.size()).data == y.data).sum() 
print(corrects)
print(len(test_iter.dataset))
  

print('test accuracy = ', corrects/len(test_iter.dataset)*100.0)
